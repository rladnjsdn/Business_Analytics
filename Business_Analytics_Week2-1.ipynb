# %% [markdown]
# # Intro to Python
#
# ### 1. Importing Images and Videos

# %%
from IPython.display import Image

# %%
Image("http://byungwan.com/class/goodjob.jpg", width=100)

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo("K5KVEU3aaeQ", width=200, height=100)

# %% [markdown]
# ### 2. Arithmetic Operators

# %%
1 + 2
# Out:
# 3

# %%
3 * 9
# Out:
# 27

# %%
a = 1
b = 2

# %%
a + b
# Out:
# 3

# %%
c = "Korea University"
d = "Business School"

# %%
c + d
# Out:
# 'Korea UniversityBusiness School'

# %%
c + " " + d
# Out:
# 'Korea University Business School'

# %% [markdown]
# ### 3. Data Type

# %%
type(a)
# Out:
# int

# %%
e = "1"

# %%
e
# Out:
# '1'

# %%
type(e)
# Out:
# str

# %%
a+1
# Out:
# 2

# %%
e + "1"
# Out:
# '11'

# %%
f = 4/7

# %%
f
# Out:
# 0.5714285714285714

# %%
type(f)
# Out:
# float

# %%
str(f)
# Out:
# '0.5714285714285714'

# %%
str(f) + '1'
# Out:
# '0.57142857142857141'

# %%
int(f)
# Out:
# 0

# %%
round(f)
# Out:
# 1

# %% [markdown]
# ### 4. Logical Operators

# %%
a == 1
# Out:
# True

# %%
a != 1
# Out:
# False

# %%
a != "1"
# Out:
# True

# %%
a > 3
# Out:
# False

# %%
age = 20

if age > 18:
    print("Beer")
else:
    print("Coke")
# Out:
# Beer

# %%
age = 9.4

if age > 18:
    print("Beer")
elif age > 10:
    print("Coke")
else:
    print("Milk")
# Out:
# Milk

# %% [markdown]
# ### 5. Array (List / Vector)

# %%
BTS = ["Jin", "Suga", "J-Hope", "RM", "Jimin", "V", "Jungkook"]

# %%
BTS[2]
# Out:
# 'J-Hope'

# %%
BTS[0:2]
# Out:
# ['Jin', 'Suga']

# %%
nums = range(0,5)

# %%
list(nums)
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# ### 6. DataFrame (Table)

# %%
from random import randint

# %%
randint(0, 100)
# Out:
# 82

# %%
import numpy as np

# %%
np.random.randint(0, 100, size=4)
# Out:
# array([36, 22, 35, 16], dtype=int32)

# %%
np.random.randint(0, 100, size=(5,4))
# Out:
# array([[79, 49, 60, 31],
#        [21, 34, 45, 51],
#        [23, 64,  8, 36],
#        [70, 21, 27,  3],
#        [16, 97, 38, 74]], dtype=int32)

# %%
values = np.random.randint(0, 100, size=(5,4))

# %%
values
# Out:
# array([[53, 94, 33, 58],
#        [54, 40, 39, 87],
#        [37, 34, 45, 89],
#        [61, 61, 41, 72],
#        [30, 16, 48, 45]], dtype=int32)

# %%
import pandas as pd

# %%
pd.DataFrame(values)
# Out:
#     0   1   2   3
# 0  53  94  33  58
# 1  54  40  39  87
# 2  37  34  45  89
# 3  61  61  41  72
# 4  30  16  48  45

# %% [markdown]
# ### 7. Function

# %%
def add(a, b, c, d):
    return (a * b + c / d)

# %%
add(1,2,3,4)
# Out:
# 2.75
