# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
url = ("http://byungwan.com/class/Coupon_Assignment.xlsx")

# %%
coupon = pd.read_excel(url)

# %%
coupon.head(10)
# Out:
#    CID  Gender  Age  CClass  Discount  Visits  Email  SMS  MStatus  Purchases  \
# 0    1       1   25       2         0       1      0    0        0          1
# 1    2       0   17       2         0       1      0    0        0          1
# 2    3       0   38       2         0       3      0    0        0          1
# 3    4       0   36       2         0       6      0    0        1          3
# 4    5       0   37       2         0       7      0    0        1          5
# 5    6       0   28       2         0       6      1    1        1          1
# 6    7       1   24       1         0       0      0    1        0          0
# 7    8       1   25       2         1       3      0    0        0          1
# 8    9       0   34       2         0       2      0    0        1          1
# 9   10       0   37       1         0       1      1    0        0          0
#
#     Sales
# 0  0.5050
# 1  0.3300
# 2  0.2550
# 3  1.8762
# 4  6.0940
# 5  0.6100
# 6  0.0000
# 7  0.2750
# ...

# %% [markdown]
# ## (a)
#
# ### A bar chart and a pie chart of Customer Class

# %%
plt.bar(coupon["CClass"], coupon["Sales"])
plt.show()

# %%
plt.pie(coupon["CClass"], )
plt.show()

# %% [markdown]
# ## (b)
#
# ### A box chart and a histogram of Sales

# %% [markdown]
# ## (c)
#
# ### A scatter plot of Sales and Discount

# %% [markdown]
# ## (d)
#
# ### A heatmap of the correlation matrix of all variables
